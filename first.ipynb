4 MB/s eta 0:00:02
#    ---------------------- ----------------- 22.6/40.9 MB 10.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 23.2/40.9 MB 10.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 23.7/40.9 MB 10.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 24.2/40.9 MB 10.6 MB/s eta 0:00:02
#    ------------------------ --------------- 24.7/40.9 MB 10.7 MB/s eta 0:00:02
#    ------------------------ --------------- 25.2/40.9 MB 10.7 MB/s eta 0:00:02
#    ------------------------- -------------- 25.7/40.9 MB 10.6 MB/s eta 0:00:02
#    ------------------------- -------------- 26.2/40.9 MB 10.6 MB/s eta 0:00:02
#    -------------------------- ------------- 26.6/40.9 MB 10.6 MB/s eta 0:00:02
#    -------------------------- ------------- 27.1/40.9 MB 10.6 MB/s eta 0:00:02
#    -------------------------- ------------- 27.5/40.9 MB 10.4 MB/s eta 0:00:02
#    --------------------------- ------------ 27.9/40.9 MB 10.4 MB/s eta 0:00:02
#    --------------------------- ------------ 28.3/40.9 MB 10.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 28.8/40.9 MB 10.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 29.2/40.9 MB 10.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 29.6/40.9 MB 10.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 30.1/40.9 MB 10.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 30.6/40.9 MB 9.9 MB/s eta 0:00:02
#    ------------------------------ --------- 31.0/40.9 MB 9.9 MB/s eta 0:00:02
#    ------------------------------ --------- 31.4/40.9 MB 10.2 MB/s eta 0:00:01
#    ------------------------------- -------- 31.8/40.9 MB 9.8 MB/s eta 0:00:01
#    ------------------------------- -------- 32.3/40.9 MB 9.8 MB/s eta 0:00:01
#    ------------------------------- -------- 32.7/40.9 MB 9.8 MB/s eta 0:00:01
#    -------------------------------- ------- 33.2/40.9 MB 9.9 MB/s eta 0:00:01
#    -------------------------------- ------- 33.6/40.9 MB 9.6 MB/s eta 0:00:01
#    --------------------------------- ------ 34.1/40.9 MB 9.8 MB/s eta 0:00:01
#    --------------------------------- ------ 34.5/40.9 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 35.0/40.9 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 35.5/40.9 MB 9.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 35.9/40.9 MB 9.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.4/40.9 MB 9.5 MB/s eta 0:00:01
#    ------------------------------------ --- 36.9/40.9 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------ --- 37.2/40.9 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------ --- 37.7/40.9 MB 9.5 MB/s eta 0:00:01
#    ------------------------------------- -- 38.2/40.9 MB 9.5 MB/s eta 0:00:01
#    ------------------------------------- -- 38.6/40.9 MB 9.6 MB/s eta 0:00:01
#    -------------------------------------- - 39.1/40.9 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 39.6/40.9 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  40.0/40.9 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  40.5/40.9 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  40.9/40.9 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  40.9/40.9 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 40.9/40.9 MB 9.0 MB/s eta 0:00:00
# Installing collected packages: scipy, patsy, statsmodels
# Successfully installed patsy-1.0.1 scipy-1.15.2 statsmodels-0.14.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
import pandas as pd

# %%
import statsmodels.api as sm

# %%
import statsmodels.formula.api as smf

# %%
nsample = 200

# %%
X1 = np.random.normal(size=nsample, loc=0, scale=1)

# %%
X2 = np.random.normal(size=nsample, loc=0, scale=1)

# %%
X3 = np.random.normal(size=nsample, loc=0, scale=1)

# %%
beta = np.array([1, 0.1, 10])

# %%
e = np.random.normal(size=nsample)

# %%
y = 3 + X1 + 0.1 * X2 + 5 * X3 + e

# %%
DF = pd.DataFrame({'X1':X1, 'X2':X2, 'X3':X3, 'y':y})

# %%
DF.head()
# Out:
#          X1        X2        X3         y
# 0 -1.878500  0.668318 -0.349718 -2.199023
# 1 -0.387501  0.064222 -1.602236 -7.074794
# 2  0.174462 -1.495695  1.067284  7.334258
# 3 -1.144869 -1.309263  0.544599  3.254952
# 4 -0.527364  1.243610 -0.507220 -0.781904

# %% [markdown]
# ## statsmodels.api.OLS 적용 결과

# %%
X = DF.loc[:, ["X1", "X2"]]

# %%
X = sm.add_constant(X)

# %%
m0 = sm.OLS(y, X)

# %%
fit0 = m0.fit()

# %%
fit0.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.122
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     13.67
# Date:                Thu, 13 Mar 2025   Prob (F-statistic):           2.76e-06
# Time:                        16:08:43   Log-Likelihood:                -615.42
# No. Observations:                 200   AIC:                             1237.
# Df Residuals:                     197   BIC:                             1247.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.4655      0.374      6.591      0.000       1.728       3.203
# X1             1.9283      0.373      5.171      0.000       1.193       2.664
# X2            -0.4864      0.392     -1.240      0.217      -1.260       0.287
# ==============================================================================
# Omnibus:                        0.550   Durbin-Watson:                   2.268
# Prob(Omnibus):                  0.760   Jarque-Bera (JB):                0.415
# Skew:                          -0.110   Prob(JB):                        0.813
# Kurtosis:                       3.036   Cond. No.                         1.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## statsmodels.formula.api.ois 적용 및 결과

# %%
m1 = smf.ols(formula='y ~ X1+X2+X3', data=DF)

# %%
fit1 = m1.fit()

# %%
fit1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                     2058.
# Date:                Thu, 13 Mar 2025   Prob (F-statistic):          7.52e-148
# Time:                        16:09:53   Log-Likelihood:                -280.29
# No. Observations:                 200   AIC:                             568.6
# Df Residuals:                     196   BIC:                             581.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9898      0.071     42.375      0.000       2.851       3.129
# X1             0.9018      0.071     12.638      0.000       0.761       1.043
# X2             0.1533      0.074      2.068      0.040       0.007       0.300
# X3             5.0334      0.069     73.471      0.000       4.898       5.168
# ==============================================================================
# Omnibus:                        4.560   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.102   Jarque-Bera (JB):                2.782
# Skew:                           0.044   Prob(JB):                        0.249
# Kurtosis:                       2.429   Cond. No.                         1.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/62/27/585859e72e117fe861c2079bcba35591a84f801e21bc1ab85bce6ce60305/scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\thsdn\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\thsdn\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.15.2)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/91/29/df4b9b42f2be0b623cbd5e2140cafcaa2bef0759a00b7b70104dcfe2fb51/joblib-1.4.2-py3-none-any.whl.metadata
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/4b/2c/ffbf7a134b9ab11a67b0cf0726453cedd9c5043a4fe7a35d1cefa9a1bcfb/threadpoolctl-3.5.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp312-cp312-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.1 MB 2.0 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/11.1 MB 6.9 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/11.1 MB 6.1 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/11.1 MB 6.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/11.1 MB 6.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.1 MB 6.8 MB/s eta 0:00:02
#    ------- -------------------------------- 2.0/11.1 MB 6.5 MB/s eta 0:00:02
#    --------- ------------------------------ 2.5/11.1 MB 7.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.0/11.1 MB 7.4 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.1 MB 7.7 MB/s eta 0:00:02
#    ------------- -------------------------- 3.8/11.1 MB 7.8 MB/s eta 0:00:01
#    --------------- ------------------------ 4.3/11.1 MB 7.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.6/11.1 MB 8.0 MB/s eta 0:00:01
#    ------------------ --------------------- 5.1/11.1 MB 8.2 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.1 MB 8.2 MB/s eta 0:00:01
#    --------------------- ------------------ 5.9/11.1 MB 8.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.4/11.1 MB 8.4 MB/s eta 0:00:01
#    ------------------------ --------------- 6.9/11.1 MB 8.5 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.1 MB 8.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.8/11.1 MB 8.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.2/11.1 MB 8.6 MB/s eta 0:00:01
#    ------------------------------ --------- 8.5/11.1 MB 8.5 MB/s eta 0:00:01
#    -------------------------------- ------- 9.0/11.1 MB 8.5 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.1 MB 8.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.9/11.1 MB 8.6 MB/s eta 0:00:01
#    ------------------------------------ --- 10.1/11.1 MB 8.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.4/11.1 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  10.9/11.1 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.1 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 8.5 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    ---------------------------------------  297.0/301.8 kB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 301.8/301.8 kB 6.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn import datasets

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.pipeline import make_pipeline

# %%
from sklearn.preprocessing import StandardScaler

# %%
X, y = datasets.load_diabetes(return_X_y=True)

# %%
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
scaler = StandardScaler().fit(X_tr)

# %%
X_tr_s = scaler.transform(X_tr)

# %%
X_te_s = scaler.transform(X_te)

# %%
lm = LinearRegression()

# %%
lm.fit(X_tr_s, y_tr)
# Out:
# LinearRegression()

# %%
print('beta_0 = ', lm.intercept_)
# Out:
# beta_0 =  154.06472491909386

# %%
print('[beta_1, ..., beta_p] = ', lm.coef_)
# Out:
# [beta_1, ..., beta_p] =  [ -0.63290115 -11.32376659  28.12590693  15.89995864 -31.56306693
#   16.35314206   4.20669415  10.37107451  32.52887279   2.23249758]

# %%
pred=  lm.predict(X_te_s)

# %%
out = pd.DataFrame({'y' : y_te,
                    'y_pred':pred,
                    'resid' : y_te - pred})

# %%
out
# Out:
#          y      y_pred       resid
# 0     78.0  117.359587  -39.359587
# 1    152.0  107.589492   44.410508
# 2    200.0  186.612242   13.387758
# 3     59.0   65.022655   -6.022655
# 4    311.0  172.786173  138.213827
# ..     ...         ...         ...
# 128  216.0  172.926666   43.073334
# 129   90.0  133.469410  -43.469410
# 130  178.0  120.763426   57.236574
# 131  122.0  192.165442  -70.165442
# 132   92.0  122.217749  -30.217749
#
# [133 rows x 3 columns]

# %%
from sklearn.metrics import mean_squared_error as MSE, r2_score as R2

# %%
print("Coefficient of determination: %.2f" % R2(y_te, pred))
# Out:
# Coefficient of determination: 0.44

# %%
print("MSE: %.2f" % MSE(y_te, pred))
# Out:
# MSE: 2827.08
